# %% [markdown]
# # Data Exploration

# %%
import requests

# %% [markdown]
# ### API Call

# %%
nyc = requests.get('https://data.cityofnewyork.us/resource/wvxf-dwi5.json').json()

# %%
nyc
# Out:
# [{'violationid': '10081311',
#   'buildingid': '375411',
#   'registrationid': '306067',
#   'boroid': '3',
#   'boro': 'BROOKLYN',
#   'housenumber': '22 FRONT',
#   'lowhousenumber': '22 FRON',
#   'highhousenumber': '22 FRONT',
#   'streetname': 'STAGG STREET',
#   'streetcode': '80930',
#   'zip': '11206',
#   'apartment': '5',
#   'story': '3',
#   'block': '3031',
#   'lot': '15',
#   'class': 'C',
#   'inspectiondate': '2013-12-30T00:00:00.000',
#   'approveddate': '2014-01-04T00:00:00.000',
#   'originalcertifybydate': '2014-01-19T00:00:00.000',
#   'originalcorrectbydate': '2014-01-14T00:00:00.000',
#   'ordernumber': '510',
#   'novid': '4752579',
#   'novdescription': '§ 27-2005 ADM CODE & 309 M/D LAW ABATE THE NUISANCE CONSISTING OF HOT WATER EXCEEDING MAXIMUM TEMPERATURE LIMIT IN THE ENTIRE APARTMENT LOCATED AT APT 5, 3rd STORY, 1st APARTMENT FROM EAST AT SOUTH',
#   'novissueddate': '2014-01-06T00:00:00.000',
#   'currentstatusid': '19',
# ...
